# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image #image function that allows us to open up images and actually then we're going to be able to 
                      #transform this image into an array that numpy can understand

# %%
pic = Image.open("img1.png")

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x137BC97D8E0>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr= np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (640, 640, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (640, 640, 3)

# %%
#Red channel values 0-255, 0->full black, 255->full pure red
plt.imshow(pic_red[:,:,0], cmap ="gray")

# %%
#Green channel values 0-255, 0->full black, 255->full pure green
plt.imshow(pic_red[:,:,1], cmap="gray")

# %%
#Blue channel values 0-255, 0->full black, 255->full pure blue
plt.imshow(pic_red[:,:,2], cmap="gray")

# %%
pic_red[:,:,1]=0

# %%
plt.imshow(pic_red)

# %%
pic_red[:,:,2]=0

# %%
plt.imshow(pic_red)

# %%
import cv2

# %%
img = cv2.imread("img2.png")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (726, 982, 3)

# %%
plt.imshow(img)

# %%
#Matplotlib --> R(ed) G(reen) B(lue)
#OpenCV --> Blue Green Red

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img);

# %%
img_gray= cv2.imread("img2.png",cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap="gray")

# %%
plt.imshow(img_gray,cmap="magma")

# %%
fix_img.shape
# Out:
# (726, 982, 3)

# %%
new_img = cv2.resize(fix_img,(1000,400))

# %%
plt.imshow(new_img)

# %%
w_ratio =0.5
h_ratio =1 # %20 of original height

# %%
new_img= cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (726, 491, 3)

# %%
new_img=cv2.flip(fix_img,0)
plt.imshow(new_img)

# %%
new_img=cv2.flip(fix_img,-1)
plt.imshow(new_img)

# %%
new_img=cv2.flip(fix_img,1)
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite("totally_new.jpg",fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
ax=fig.add_subplot(111)
ax.imshow(fix_img);

# %%
fig = plt.figure(figsize=(2,2))
ax=fig.add_subplot(111)
ax.imshow(fix_img);

# %%
fig = plt.figure(figsize=(10,8))
ax=fig.add_subplot(888)
ax.imshow(fix_img);

# %%
img = cv2.imread("img1.png")
cv2.imshow("Kitty", img)
cv2.waitKey()
# Out:
# -1
